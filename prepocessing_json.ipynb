# %% [markdown]
# #### Data exploration

# %%
# import json
# with open('./json_data/anger.json') as f:
#     anger_json = json.load(f)

# %%
# type(anger_json)

# %%
# len(anger_json)

# %%
# anger_json_0=anger_json[0]
# anger_json_0

# %%
# anger_json_0['annot_A']['boxes']['maxX']

# %%
# anger_json_0_X=anger_json_0['annot_A']['boxes']['maxX'] 
# anger_json_0_X

# %%
# anger_json_0['filename']

# %%
# anger_rows = []
# for i, a_json in enumerate(anger_json):
#     anger_rows.append (['0_{}'.format(i), 
#                 a_json['annot_A']['boxes']['maxX'], 
#                 a_json['annot_A']['boxes']['maxX'],
#                 a_json['annot_A']['boxes']['maxX'],
#                 a_json['annot_A']['boxes']['maxX'],
#                 a_json['filename'],
#                 0
#                 ])

# %%
# anger_rows[:5]

# %%
# len(anger_rows)

# %%
import cv2

# %% [markdown]
# #### Korean_emotion.csv +  anger(0) csv

# %%
# from os import path 
# # Korean_emotion.csv -> (index, minx, maxy , miny, maxy, file_name,emotion)

# head = ['index','min_x','max_y','min_y','mix_y','filename','emotion']
# try:
#     if path.isfile('Korean_emotion.csv')== False:
#         with open('Korean_emotion.csv' , mode='w', newline='',encoding = 'utf-8-sig') as f:
#                         csv_writer = csv.writer(f,delimiter=',',quotechar='"',quoting=csv.QUOTE_MINIMAL)
#                         csv_writer.writerow(head)
#         f.close()
    

#     if path.isfile('Korean_emotion.csv')== True:
#         for i,a_row in enumerate(anger_rows): 
#             with open('Korean_emotion.csv',mode='a',newline='', encoding = 'utf-8-sig') as f:
#                             csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                             csv_writer.writerow(a_row, encoding = '')
                            
#             f.close()
# except:
#     pass

# %% [markdown]
# #### + neutral(1) csv

# %%
# import json
# with open('./json_data/neutral.json') as f:
#     neutral_json = json.load(f)

# %%
# neutral_rows = []
# for i, a_json in enumerate(neutral_json):
#     neutral_rows.append (['1_{}'.format(i), 
#                 a_json['annot_A']['boxes']['maxX'], 
#                 a_json['annot_A']['boxes']['maxX'],
#                 a_json['annot_A']['boxes']['maxX'],
#                 a_json['annot_A']['boxes']['maxX'],
#                 a_json['filename'],
#                 1
#                 ])

# %%
# len(neutral_rows)

# %%
# neutral_rows[:5]

# %%
# Korean_emotion.csv -> (index, minx, maxy , miny, maxy, file_name,emotion)
# import csv 
# from os import path


# try:
  
#     if path.isfile('Korean_emotion.csv')== True:
#         print('true')
#         for i,n_row in enumerate(neutral_rows): 
#             print('1')
#             with open('Korean_emotion.csv',mode='a',newline='') as f:
#                             print('2')
#                             csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                             csv_writer.writerow(n_row)
#                             print(i)
                            
#             f.close()
# except:
#     pass

# %%
# import json
# with open('./json_data/neutral.json') as f:
#     sad_json = json.load(f)

# %%
# sad_rows = []
# for i, s_json in enumerate(sad_json):
#     sad_rows.append (['2_{}'.format(i), 
#                 a_json['annot_A']['boxes']['maxX'], 
#                 a_json['annot_A']['boxes']['maxX'],
#                 a_json['annot_A']['boxes']['maxX'],
#                 a_json['annot_A']['boxes']['maxX'],
#                 a_json['filename'],
#                 2
#                 ])

# %%
# len(sad_rows)

# %%
# sad_rows[:5]

# %%
# import csv 
# from os import path


# try:
  
#     if path.isfile('Korean_emotion.csv')== True:
#         print('true')
#         for i,s_row in enumerate(sad_rows): 
#             print('1')
#             with open('Korean_emotion.csv',mode='a',newline='') as f:
#                             print('2')
#                             csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                             csv_writer.writerow(s_row)
#                             print(i)
                            
#             f.close()
# except:
#     pass

# %% [markdown]
# ### csv= [emotion- index, min_x ,max_x,min_y, max_y, filename, emotion ]
#
# #### emotion anger=0, neutral=1, sad=2

# %%
import pandas as pd

# %%
import glob

# %%
# base_path = 'd:/Korean_emotion'
# imgs_0 = plt.imread(base_path+'/image_data/0/{}'.format(df['filename'][1]))
# # imgs_1 = plt.imread('./image_data/1/*.jpg')
# # imgs_2= plt.imread('./image_data/2/*.jpg')

# plt.subplot(1,3,1)
# plt.imshow(imgs_0)
# plt.title('angry')

# # plt.subplot(1,3,2)
# # plt.imshow(random.choice(imgs_1))
# # plt.title('neutral')

# # plt.subplot(1,3,3)
# # plt.imshow(random.choice(imgs_2))
# # plt.title('sad')

# %%
df['filename'][:5]

# %%
imgs_0 = glob.glob('./image_data/0/*.jpg')
print(imgs_0[1])
type(imgs_0)

# %%
# image 이름 

imgs_0 = glob.glob('./image_data/0/*.jpg')
img0_names=[]
for img0 in imgs_0:
    img0_names.append(img0.split('\\')[1])
    
print(len(img0_names), len(df[df['emotion']==0]))
# Out:
# 7296 7461

# %%
# csv 파일 
filename_0 = [name for name,emotion in zip(df['filename'], df['emotion']) if emotion ==0 ]

for name in filename_0:
    if name not in img0_names:
        df.drop(df[df['filename'] == name].index , inplace=True)

len(df[df['emotion']==0]), len(img0_names)
# Out:
# (7296, 7296)

# %%
# file match check 
from PIL import Image
import matplotlib.pyplot as plt

imgs0_path= './image_data/0/{}'.format(filename_0[0])

image= Image.open(imgs0_path)

plt.imshow(image)
plt.axis('off')
plt.show()

# %%
# df.to_csv('korean_emotion0.csv', index=False, encoding='utf-8-sig' )

# %% [markdown]
# -----------------------------------------------

# %%
# df= pd.read_csv('korean_emotion0.csv', encoding='utf-8-sig')
# df
# Out:
#         index        min_x        max_y        min_y        mix_y  \
# 0         0_0  1932.131500  1932.131500  1932.131500  1932.131500
# 1         0_1  2148.216300  2148.216300  2148.216300  2148.216300
# 2         0_2  2306.475600  2306.475600  2306.475600  2306.475600
# 3         0_3  1885.722900  1885.722900  1885.722900  1885.722900
# 4         0_4  1925.137500  1925.137500  1925.137500  1925.137500
# ...       ...          ...          ...          ...          ...
# 22012  0_7474  1537.679600  1537.679600  1537.679600  1537.679600
# 22013  0_7475  2489.923358  2489.923358  2489.923358  2489.923358
# 22014  0_7476  1503.243055  1503.243055  1503.243055  1503.243055
# 22015  0_7477  1309.637600  1309.637600  1309.637600  1309.637600
# 22016  0_7478  1831.830598  1831.830598  1831.830598  1831.830598
#
#                                                 filename  emotion
# 0      8eda43d87e4ef16a231f97114c20d59660b02b99514db5...        0
# ...

# %%
imgs_1 = glob.glob('./image_data/1/*.jpg')
img1_names=[]
for img1 in imgs_1:
    img1_names.append(img1.split('\\')[1])
    
print(img1_names[:3])
print(len(img1_names))
# Out:
# ['006b56dc2f8cda2361e1b01b2496d6f352dd5b1790f0a9b0bfcbe540b292247d_여_20_중립_공공시설&종교&의료시설_20210130215826-001-006.jpg', '006b56dc2f8cda2361e1b01b2496d6f352dd5b1790f0a9b0bfcbe540b292247d_여_20_중립_상업시설&점포&시장_20210130220011-003-006.jpg', '006b56dc2f8cda2361e1b01b2496d6f352dd5b1790f0a9b0bfcbe540b292247d_여_20_중립_숙박 및 거주공간_20210130220424-010-001.jpg']
# 6677

# %%
filename_1 = [name for name,emotion in zip(df['filename'], df['emotion']) if emotion ==1 ]

for name in filename_1:
    if name not in img1_names:
        df.drop(df[df['filename'] == name].index , inplace=True)

print(len(img1_names), len(df[df['emotion']==1]))
# Out:
# 6677 6676

# %%
# df.drop(df[df['filename']==filename_1[4]].index, inplace=True)
# print(len(img1_names), len(df[df['emotion']==1]))
# Out:
# 6677 6676

# %%
for name in filename_1:
    if name not in img1_names:
        filename_1.remove(name)

# %%
for name in filename_0:
    if name not in img0_names:
        filename_0.remove(name)

# %%
for name in filename_2:
    if name not in img2_names:
        filename_2.remove(name)

# %%
# file match check 
from PIL import Image
import matplotlib.pyplot as plt

emotion=1

imgs_path= './image_data/1/{}'.format(filename_1[5])

image= Image.open(imgs_path)

plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ------------------

# %%
# df=pd.read_csv('korean_emotion1.csv', encoding='utf-8-sig',header=0  )

# %%
imgs_2 = glob.glob('./image_data/2/*.jpg')
img2_names=[]
for img2 in imgs_2:
    img2_names.append(img2.split('\\')[1])
    
# print(img2_names[:3])
print(len(img2_names))

# %%
filename_2 = [name for name,emotion in zip(df['filename'], df['emotion']) if emotion ==2 ]

for name in filename_2:
    if name not in img2_names:
        df.drop(df[df['filename'] == name].index , inplace=True)

print(len(img2_names), len(df[df['emotion']==2]))

# %%
df.to_csv('korean_emotion2.csv', index=False, encoding='utf-8-sig' )

# %% [markdown]
# ----

# %%
# df = pd.read_csv('korean_emotion2.csv', encoding = 'utf-8-sig')
# df
# # df['filename'][0]

# %%
len(df[df['emotion']==0]),len(df[df['emotion']==1]),len(df[df['emotion']==2])

# %%
for name in filename_1:
    if name not in img1_names:
        filename_1.remove(name)

# %%
for name in filename_0:
    if name not in img0_names:
        filename_0.remove(name)

# %%
for name in filename_2:
    if name not in img2_names:
        filename_2.remove(name)

# %%
# # file match check 
# from PIL import Image
# import matplotlib.pyplot as plt

# emotion=2

# imgs_path= './image_data/{}/{}'.format(emotion,filename_2[5])

# image= Image.open(imgs_path)

# plt.imshow(image)
# plt.axis('off')
# plt.show()

# %%
# df.to_csv('korean_emotion2.csv', index=False, encoding='utf-8-sig' )

# %%
# df = pd.read_csv('korean_emotion2.csv',  encoding='utf-8-sig' )

# %%
# df
# Out:
#         index        min_x        max_y        min_y        mix_y  \
# 0         0_0  1932.131500  1932.131500  1932.131500  1932.131500
# 1         0_1  2148.216300  2148.216300  2148.216300  2148.216300
# 2         0_2  2306.475600  2306.475600  2306.475600  2306.475600
# 3         0_3  1885.722900  1885.722900  1885.722900  1885.722900
# 4         0_4  1925.137500  1925.137500  1925.137500  1925.137500
# ...       ...          ...          ...          ...          ...
# 21286  0_7474  1537.679600  1537.679600  1537.679600  1537.679600
# 21287  0_7475  2489.923358  2489.923358  2489.923358  2489.923358
# 21288  0_7476  1503.243055  1503.243055  1503.243055  1503.243055
# 21289  0_7477  1309.637600  1309.637600  1309.637600  1309.637600
# 21290  0_7478  1831.830598  1831.830598  1831.830598  1831.830598
#
#                                                 filename  emotion
# 0      8eda43d87e4ef16a231f97114c20d59660b02b99514db5...        0
# ...

# %%
# len(df[df['emotion']==0]),len(df[df['emotion']==1]),len(df[df['emotion']==2])
# Out:
# (7296, 6676, 7319)

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv('Korean_emotion.csv', encoding= 'CP949')

# %%
df
# Out:
#         index        min_x        max_x        min_y        max_y  \
# 0         0_0  1932.131500  1932.131500  1932.131500  1932.131500
# 1         0_1  2148.216300  2148.216300  2148.216300  2148.216300
# 2         0_2  2306.475600  2306.475600  2306.475600  2306.475600
# 3         0_3  1885.722900  1885.722900  1885.722900  1885.722900
# 4         0_4  1925.137500  1925.137500  1925.137500  1925.137500
# ...       ...          ...          ...          ...          ...
# 21286  0_7474  1537.679600  1537.679600  1537.679600  1537.679600
# 21287  0_7475  2489.923358  2489.923358  2489.923358  2489.923358
# 21288  0_7476  1503.243055  1503.243055  1503.243055  1503.243055
# 21289  0_7477  1309.637600  1309.637600  1309.637600  1309.637600
# 21290  0_7478  1831.830598  1831.830598  1831.830598  1831.830598
#
#                                                 filename  emotion
# 0      8eda43d87e4ef16a231f97114c20d59660b02b99514db5...        0
# ...

# %%
df['filename'][0]
# Out:
# '8eda43d87e4ef16a231f97114c20d59660b02b99514db5e06597b1c903e59b05_남_30_분노_상업시설&점포&시장_20201207151501-003-014.jpg'

# %%
filename_0 = [name for name,emotion in zip(df['filename'], df['emotion']) if emotion ==0 ]
filename_1 = [name for name,emotion in zip(df['filename'], df['emotion']) if emotion ==1 ]
filename_2 = [name for name,emotion in zip(df['filename'], df['emotion']) if emotion ==2 ]

# %%
# file match check 
from PIL import Image
import matplotlib.pyplot as plt

emotion=2
idx =10

imgs_path= './image_data/{}/{}'.format(emotion,filename_2[idx])

image= Image.open(imgs_path)

plt.imshow(image)
plt.axis('off')
plt.show()

# %%
df['index'][df['filename']==filename_2[idx]]
# Out:
# 13982    0_10
# Name: index, dtype: object

# %%
# index_list = df[df['emotion'] == 2]['index'].tolist()
# new = [i.replace('0_', '2_') for i in index_list]


# df.loc[df['emotion'] == 2, 'index'] = new
# df.to_csv('Korean_emotion3.csv', index=False)

# %% [markdown]
# -----------------------------------------------------------------
# ### csv done!
#
# ### csv= [emotion- index, min_x ,max_x,min_y, max_y, filename, emotion ]
#
# #### emotion anger=0, neutral=1, sad=2

# %% [markdown]
# _____________________________________________________________________________________

# %%
df = pd.read_csv('Korean_emotion3.csv', encoding= 'utf-8-sig')

# %%
df
# Out:
#         index        min_x        max_x        min_y        max_y  \
# 0         0_0  1932.131500  1932.131500  1932.131500  1932.131500
# 1         0_1  2148.216300  2148.216300  2148.216300  2148.216300
# 2         0_2  2306.475600  2306.475600  2306.475600  2306.475600
# 3         0_3  1885.722900  1885.722900  1885.722900  1885.722900
# 4         0_4  1925.137500  1925.137500  1925.137500  1925.137500
# ...       ...          ...          ...          ...          ...
# 21286  2_7474  1537.679600  1537.679600  1537.679600  1537.679600
# 21287  2_7475  2489.923358  2489.923358  2489.923358  2489.923358
# 21288  2_7476  1503.243055  1503.243055  1503.243055  1503.243055
# 21289  2_7477  1309.637600  1309.637600  1309.637600  1309.637600
# 21290  2_7478  1831.830598  1831.830598  1831.830598  1831.830598
#
#                                                 filename  emotion
# 0      8eda43d87e4ef16a231f97114c20d59660b02b99514db5...        0
# ...

# %%
df['filename'] = df['filename'].str.split('_').str[-1]
df.to_csv('Korean_emoition4.csv', index = False)

# %%
df
# Out:
#         index        min_x        max_x        min_y        max_y  \
# 0         0_0  1932.131500  1932.131500  1932.131500  1932.131500
# 1         0_1  2148.216300  2148.216300  2148.216300  2148.216300
# 2         0_2  2306.475600  2306.475600  2306.475600  2306.475600
# 3         0_3  1885.722900  1885.722900  1885.722900  1885.722900
# 4         0_4  1925.137500  1925.137500  1925.137500  1925.137500
# ...       ...          ...          ...          ...          ...
# 21286  2_7474  1537.679600  1537.679600  1537.679600  1537.679600
# 21287  2_7475  2489.923358  2489.923358  2489.923358  2489.923358
# 21288  2_7476  1503.243055  1503.243055  1503.243055  1503.243055
# 21289  2_7477  1309.637600  1309.637600  1309.637600  1309.637600
# 21290  2_7478  1831.830598  1831.830598  1831.830598  1831.830598
#
#                          filename  emotion
# 0      20201207151501-003-014.jpg        0
# 1      20201202185830-003-001.jpg        0
# ...

# %%
# import os
# imagedir='./image_data/0/'
# imgs_0 = os.listdir('./image_data/0/')
# imgs_0
# for name in imgs_0:
#     newname=name.split('_')[-1]
#     org = os.path.join(imagedir,name)
#     new = os.path.join(imagedir,newname)

#     os.rename(org, new)

# %%
filename_0 = [name for name,emotion in zip(df['filename'], df['emotion']) if emotion ==0 ]
filename_1 = [name for name,emotion in zip(df['filename'], df['emotion']) if emotion ==1 ]
filename_2 = [name for name,emotion in zip(df['filename'], df['emotion']) if emotion ==2 ]

# %%
filename_0[0]
# Out:
# '20201207151501-003-014.jpg'

# %%
'0_'+filename_0[0]
# Out:
# '0_20201207151501-003-014.jpg'

# %%
newfilename=[]
for name in filename_0:
    new0='0_'+name
    newfilename.append(new0)

for name in filename_1:
    new1='1_'+name
    newfilename.append(new1)

for name in filename_2:
    new2='2_'+name
    newfilename.append(new2)

# %%
len(newfilename)
# Out:
# 21291

# %%
# file match check 
from PIL import Image
import matplotlib.pyplot as plt

emotion=2
idx =10

imgs_path= 'd:/Korean_emotion/image_data/{}/{}'.format(emotion,filename_2[idx])

image= Image.open(imgs_path)

plt.imshow(image)
plt.axis('off')
plt.show()

# %%
imgs_path
imgs_name=df[df['index']=='{}_{}'.format(emotion, idx)]['filename']

# %%
imgs_name
# Out:
# 13982    20201201130746-007-013.jpg
# Name: filename, dtype: object

# %%
face_cascade= cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')

# %%
image= cv2.imread(imgs_path)
img = image.copy()
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    # cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,0), 2)
    roi = image[y: y+h, x: x+w]
    resize = cv2.resize(roi, (180,180), interpolation=cv2.INTER_CUBIC)
    # cv2.imshow("cropped", resize)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
    print('1')
    cv2.imwrite('d:/Korean_emotion/{}.jpg'.format(df['index']), resize)
    print('2')
# Out:
# 1
# 2

# %%
len(newfilename), newfilename[-1]
# Out:
# (21291, '2_20210215111822-002-001.jpg')

# %%
# https://github.com/opencv/opencv/tree/master/data/haarcascades

# %%
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader


class DataHandle:
    
    def __init__(self):
        self.db = []
        self.img = None
        self.new_file_path = ''


    def _detect_crop_img(self, img_path):
        try:
            self.img= cv2.imread(img_path)
            plt.subplot(1,3,i+1)
            print(i)
            plt.imshow(self.img)
                                           
            face_cascade = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
            gray = cv2.cvtColor(self.img, cv2.COLOR_BGR2GRAY)
            plt.subplot(1,3,i+1)
            print(i)
            plt.imshow(gray)
        
            faces = face_cascade.detectMultiScale(gray, 1.3, 5)
            for (x,y,w,h) in faces:
                if w<1252 or h<1252: 
                    return False

                else:
                    img = self.img.copy()
                    roi = img[y:y+h,x:x+w]
                    resize = cv2.resize(roi,(96,96), interpolation=cv2.INTER_CUBIC)
                    

                    self.img= resize
                    # plt.subplot(1,3,i+1)
                    # print(i)
                    # plt.imshow(gray)
                    return True

        except:
            return False

    # def get_transfroms():
    #     transform = transforms.Compose([
    #     transforms.RandomResizedCrop(224),  # 무작위 크롭 및 크기 조절
    #     transforms.RandomHorizontalFlip(),  # 무작위 수평 뒤집기
    #     transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # 색상 변조
    #     transforms.ToTensor(),  # 이미지를 텐서로 변환
    #     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # 이미지 정규화
    # ])
    # return transform        

    def augmentation(self, image):


            
   
    def work(self, img_path,folder):
        # for i, newname in enumerate(newfilename):
        #     print(newname)
        
        #     (emotion,name) =newname.split('_')
        #     img_path = f"./image_data/{emotion}/{name}"

            self.img = cv2.imread(img_path)
            # plt.subplot(1,3,i+1)
            # plt.imshow(img)
                  
            if  self._detect_crop_img(img_path): # True
                
                plt.subplot(1,3,i+1)
                plt.imshow(img)

                self.new_file_path = f'./{folder}/{emotion}_{name}'
                self.db.append({
                    'path': self.new_file_path,
                    'emotion': emotion
                })

                cv2.imwrite(self.new_file_path, self.img)
                # plt.imshow(self.img)

# %%
test=[newfilename[0], newfilename[1], newfilename[2]]

# %%
test
# Out:
# ['0_20201207151501-003-014.jpg',
#  '0_20201202185830-003-001.jpg',
#  '0_20210127132913-010-007.jpg']

# %%
data_handler= DataHandle()

# %%
for i, newname in enumerate(test):
            print(newname)
            (emotion,name) =newname.split('_')
            print(emotion)
            print(name)
            img_path = f"./image_data/{emotion}/{name}"
            print(img_path)
            data_handler.work(img_path,'crop' )
# Out:
# 0_20201207151501-003-014.jpg
# 0
# 20201207151501-003-014.jpg
# ./image_data/0/20201207151501-003-014.jpg
# 0
# 0_20201202185830-003-001.jpg
# 0
# 20201202185830-003-001.jpg
# ./image_data/0/20201202185830-003-001.jpg
# 1
# 0_20210127132913-010-007.jpg
# 0
# 20210127132913-010-007.jpg
# ./image_data/0/20210127132913-010-007.jpg
# 2

# %%
data_handle = DataHandle()
data_handle.work(test,'crop' )
# Out:
# 0_20201207151501-003-014.jpg
# 2
# 0_20201202185830-003-001.jpg
# 2
# 0_20210127132913-010-007.jpg
# 2

# %% [markdown]
# ![image.png](attachment:image.png)
# ###### -> 문제 : 넘어가고 나서 이미지 안변한다.

# %%
from PIL import Image
import matplotlib.pyplot as plt

for i,newname in enumerate(test):

    plt.subplot(1,3,i+1)
    (emotion,name) =newname.split('_')
    img_path = f"./image_data/{emotion}/{name}"
    image=Image.open(img_path)
    plt.imshow(image)
    plt.show()

# %%
test
# Out:
# ['0_20201207151501-003-014.jpg', '0_20201202185830-003-001.jpg']

# %%
###  face detect failed 

newname= '0_20201207151501-003-014.jpg'

     
(emotion,name) =newname.split('_')
img_path = f"./image_data/{emotion}/{name}"
img = cv2.imread(img_path)




# face_cascade = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# faces = face_cascade.detectMultiScale(gray, 1.3, 5)


for (x,y,w,h) in faces:
    roi = img[
        y:y+h,
        x:x+w
        ]
resize = cv2.resize(roi, (96, 96), interpolation=cv2.INTER_CUBIC)


plt.imshow(resize)

# %%
###  face detect failed 

newname= '0_20201207151501-003-014.jpg'

     
(emotion,name) =newname.split('_')
img_path = f"./image_data/{emotion}/{name}"
img = cv2.imread(img_path)


face_cascade = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    roi = img[
        y:y+h,
        x:x+w
        ]
resize = cv2.resize(roi, (96, 96), interpolation=cv2.INTER_CUBIC)


plt.imshow(resize)

# %%
###  face detect failed _removed grayscale_ failed

newname='0_20201207151501-003-014.jpg'
     
(emotion,name) =newname.split('_')
img_path = f"./image_data/{emotion}/{name}"
img = plt.imread(img_path)
face_cascade = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(img, 1.3, 5) # 
for (x,y,w,h) in faces:
    roi = img[
        y:y+h,
        x:x+w
        ]
resize = cv2.resize(roi, (96, 96), interpolation=cv2.INTER_CUBIC)

print(w,h)
plt.imshow(resize)
# Out:
# 226 226

# %%
###  face detect sucess

newname='0_20201202185830-003-001.jpg'
     
(emotion,name) =newname.split('_')
img_path = f"./image_data/{emotion}/{name}"
img = plt.imread(img_path)
face_cascade = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    

    roi = img[ y:y+h, x:x+w]
resize = cv2.resize(roi, (96, 96), interpolation=cv2.INTER_CUBIC)

print(w,h)
plt.imshow(resize)
# Out:
# 1252 1252

# %%
###  face detect sucess_removed gray

newname='0_20201202185830-003-001.jpg'
     
(emotion,name) =newname.split('_')
img_path = f"./image_data/{emotion}/{name}"
img = plt.imread(img_path)
face_cascade = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(img, 1.3, 5)
for (x,y,w,h) in faces:
    roi = img[
        y:y+h,
        x:x+w
        ]
resize = cv2.resize(roi, (96, 96), interpolation=cv2.INTER_CUBIC)

print(w,h)
plt.imshow(resize)
# Out:
# 1252 1252

# %%
datahandler=DataHandle()

datahandler.work(test,'crop')

# %%
import glob
import os

# %%
crops=os.listdir('d:/Korean_emotion/crop/')
crops
# len(crops)
image_0 = [c for c in crops if c.startswith("0_")]
print(len(image_0))
image_1 = [c for c in crops if c.startswith("1_")]
print(len(image_1))
image_2 = [c for c in crops if c.startswith("2_")]
print(len(image_2))
# Out:
# 4888
# 4608
# 4179

# %%
row1 =[] 
for name in image_1:
    row1.append(['d:/Korean_emotion/crop/'+ name,1])
row1[:5]
# Out:
# [['d:/Korean_emotion/crop/1_20201201132755-001-006.jpg', 1],
#  ['d:/Korean_emotion/crop/1_20201201132755-001-010.jpg', 1],
#  ['d:/Korean_emotion/crop/1_20201201132755-001-015.jpg', 1],
#  ['d:/Korean_emotion/crop/1_20201201132808-002-011.jpg', 1],
#  ['d:/Korean_emotion/crop/1_20201201132822-003-006.jpg', 1]]

# %%
row2 =[] 
for name in image_2:
    row2.append(['d:/Korean_emotion/crop/'+ name,2])
row2[:5]
# Out:
# [['d:/Korean_emotion/crop/2_20201201130605-001-012.jpg', 2],
#  ['d:/Korean_emotion/crop/2_20201201130605-001-013.jpg', 2],
#  ['d:/Korean_emotion/crop/2_20201201130622-002-017.jpg', 2],
#  ['d:/Korean_emotion/crop/2_20201201130638-003-006.jpg', 2],
#  ['d:/Korean_emotion/crop/2_20201201130638-003-008.jpg', 2]]

# %%
neutal  sad

# %%
# import csv
# from os import path 

# # Korean_emotion.csv -> path, emotion 
# head = ['path', 'emotion']

# try:
#     if not path.isfile('neutral_sad.csv'):
#         with open('neutral_sad.csv', mode='w', newline='', encoding='utf-8-sig') as f:
#             csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#             csv_writer.writerow(head)

#     if path.isfile('neutral_sad.csv'):
#         with open('neutral_sad.csv', mode='a', newline='', encoding='utf-8-sig') as f:
#             csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#             for row in row1:
#                 csv_writer.writerow(row)
#                 print(row)

# except Exception as e:
#     print("An error occurred:", e)

# %%
# import csv
# from os import path 


# head = ['path', 'emotion']

# try:
#     if not path.isfile('neutral_sad.csv'):
#         with open('neutral_sad.csv', mode='w', newline='', encoding='utf-8-sig') as f:
#             csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#             csv_writer.writerow(head)

#     if path.isfile('neutral_sad.csv'):
#         with open('neutral_sad.csv', mode='a', newline='', encoding='utf-8-sig') as f:
#             csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#             print('1')
#             for row in row2:
#                 csv_writer.writerow(row)
#                 print(row)

# except Exception as e:
#     print("An error occurred:", e)

# %% [markdown]
# ------------

# %%
class DataHandle:
    
    def __init__(self):
        self.db = []
        self.img = None
        self.new_file_path = ''


    def _detect_crop_img(self, img_path):
        try:
            self.img= cv2.imread(img_path)
            plt.subplot(1,3,i+1)
            print(i)
            plt.imshow(self.img)
                                           
            face_cascade = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
            gray = cv2.cvtColor(self.img, cv2.COLOR_BGR2GRAY)
            plt.subplot(1,3,i+1)
            print(i)
            plt.imshow(gray)
        
            faces = face_cascade.detectMultiScale(gray, 1.3, 5)
            for (x,y,w,h) in faces:
                if w<1252 or h<1252: 
                    return False

                else:
                    img = self.img.copy()
                    roi = img[y:y+h,x:x+w]
                    resize = cv2.resize(roi,(96,96), interpolation=cv2.INTER_CUBIC)
                    

                    self.img= resize
                    # plt.subplot(1,3,i+1)
                    # print(i)
                    # plt.imshow(gray)
                    return True

        except:
            return False

    def _get_transfroms(self):
        transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),  # 무작위 수평 뒤집기
        transforms.ToTensor(),  # 이미지를 텐서로 변환
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # 이미지 정규화
    ])
        return transform        

    def augmentation(self, image):
        transform = _get_transforms()
        augmented_image = transform(image)
        return augmented_image

   
    def work(self, img_path,folder):
        # for i, newname in enumerate(newfilename):
        #     print(newname)
        
        #     (emotion,name) =newname.split('_')
        #     img_path = f"./image_data/{emotion}/{name}"

            self.img = cv2.imread(img_path)
            # plt.subplot(1,3,i+1)
            # plt.imshow(img)
                  
            if  self._detect_crop_img(img_path): # True
                
                plt.subplot(1,3,i+1)
                plt.imshow(img)

                self.new_file_path = f'./{folder}/{emotion}_{name}'
                self.db.append({
                    'path': self.new_file_path,
                    'emotion': emotion
                })

                cv2.imwrite(self.new_file_path, self.img)
                # plt.imshow(self.img)

# %%
    # def data_augmentation(self, img):
    #     def random_noise(x):
    #         x = x + np.random.normal(size=x.shape) * np.random.uniform(1, 5)
    #         x = x - x.min()
    #         x = x / x.max()
            
    #         return x * 255.0
        
    #     datagen = ImageDataGenerator(
    #         rotation_range=40,
    #         width_shift_range=0.07,
    #         height_shift_range=0.07,
    #         shear_range=0.2,
    #         zoom_range=0.2,
    #         horizontal_flip=True,
    #         fill_mode='nearest',
    #         preprocessing_function=random_noise
    #     )
        
    #     i = 0
    #     for _ in datagen.flow(img, batch_size=16, save_to_dir='./augmentation', save_prefix=os.path.basename(self.new_file_path).split('.')[0], save_format='jpg'):
    #         i += 1
    #         if i > 5:
    #             break
            
    #     augmentation_img_list = glob.glob(os.path.join('./augmentation', '*.jpg'))
    #     for item in augmentation_img_list:
    #         item_name = os.path.basename(item)
    #         new_item_path = f'./dataset/{item_name}'
    #         self.db.append({
    #                 'path': new_item_path,
    #                 'label': item_name.split('_')[0]
    #             })
    #         os.rename(item, new_item_path)
            
    
    # def work(self, img_path):
    #     ( emotion, _) = img_path.split('_')[1].split('/')
    #     if  self._detect_crop_img():
    #         self.new_file_path = f'./dataset/{self.emotion[emotion]}_{self._random_name()}.jpg'
    #         self.db.append({
    #             'path': self.new_file_path,
    #             'label': self.emotion[emotion]
    #         })
    #         cv2.imwrite(self.new_file_path, self.img)

# %%
# 1. 모델 생성 
# 2. load model
# 3. mediapipe 캡처 이미지 저장  분노t , 슬픔f, 무표정t 
# 4. 평균 
# 4. test 하기

# %% [markdown]
# ### Augmentation

# %%
# crop data
# cvtColor 
# augmentation
#
